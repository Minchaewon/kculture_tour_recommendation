# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'NanumBarunGothic'

# %%
# 데이터 불러오기
filename  = 'C:/Users/mcw08/OneDrive/바탕 화면/OUTLIER(23상반기)/문화데이터 공모전/데이터/미디어콘텐츠 영상 내 유명지 데이터.csv'

df_media = pd.read_csv(filename,  encoding='cp949')
df_media
# Out:
#        SEQ_NO MEDIA_TY                     TITLE_NM      PLACE_NM    PLACE_TY  \
# 0           1    drama          (아는 건 별로 없지만) 가족입니다          커피파머        cafe
# 1           2    drama          (아는 건 별로 없지만) 가족입니다  셀렉토커피 남양주호평점        cafe
# 2           3    drama          (아는 건 별로 없지만) 가족입니다        카페 그루비        cafe
# 3           4    drama          (아는 건 별로 없지만) 가족입니다        미리내 성지  playground
# 4           5    drama          (아는 건 별로 없지만) 가족입니다           초은당  playground
# ...       ...      ...                          ...           ...         ...
# 15029   15030    drama  You Raise Me Up (유 레이즈 미 업)   서울마리나 클럽&요트  playground
# 15030   15031    drama  You Raise Me Up (유 레이즈 미 업)          한강대교  playground
# 15031   15032    drama  You Raise Me Up (유 레이즈 미 업)      해밀톤 호텔별관        stay
# 15032   15033    drama  You Raise Me Up (유 레이즈 미 업)        북촌로5가길  playground
# 15033   15034    drama  You Raise Me Up (유 레이즈 미 업)           청계천  playground
#
# ...

# %%
# ADDR 열의 데이터에서 앞에서 두 글자만 추출하여 중복값 없이 출력
extracted_values = df_media['ADDR'].str[:2].unique()
print(extracted_values)
len(extracted_values)  # 지역 개수 파악
# Out:
# ['경기' '서울' '인천' '전라' '충청' '강원' '부산' '경상' '대구' '제주' '광주' '대전' '울산' '세종']
# 14

# %%
# ADDR_area 열 추가(기존 데이터프레임에 지역명 열을 새로 추가 => 서울, 경기, 인천 ...)
df_media['ADDR_area'] = df_media['ADDR'].str[:2]

# 결과 확인
df_media
# Out:
#        SEQ_NO MEDIA_TY                     TITLE_NM      PLACE_NM    PLACE_TY  \
# 0           1    drama          (아는 건 별로 없지만) 가족입니다          커피파머        cafe
# 1           2    drama          (아는 건 별로 없지만) 가족입니다  셀렉토커피 남양주호평점        cafe
# 2           3    drama          (아는 건 별로 없지만) 가족입니다        카페 그루비        cafe
# 3           4    drama          (아는 건 별로 없지만) 가족입니다        미리내 성지  playground
# 4           5    drama          (아는 건 별로 없지만) 가족입니다           초은당  playground
# ...       ...      ...                          ...           ...         ...
# 15029   15030    drama  You Raise Me Up (유 레이즈 미 업)   서울마리나 클럽&요트  playground
# 15030   15031    drama  You Raise Me Up (유 레이즈 미 업)          한강대교  playground
# 15031   15032    drama  You Raise Me Up (유 레이즈 미 업)      해밀톤 호텔별관        stay
# 15032   15033    drama  You Raise Me Up (유 레이즈 미 업)        북촌로5가길  playground
# 15033   15034    drama  You Raise Me Up (유 레이즈 미 업)           청계천  playground
#
# ...

# %%
df_media_new = df_media[['MEDIA_TY', 'TITLE_NM', 'PLACE_NM', 'PLACE_TY', 'ADDR', 'LC_LA', 'LC_LO', 'ADDR_area']].copy()
df_media_new
# Out:
#       MEDIA_TY                     TITLE_NM      PLACE_NM    PLACE_TY  \
# 0        drama          (아는 건 별로 없지만) 가족입니다          커피파머        cafe
# 1        drama          (아는 건 별로 없지만) 가족입니다  셀렉토커피 남양주호평점        cafe
# 2        drama          (아는 건 별로 없지만) 가족입니다        카페 그루비        cafe
# 3        drama          (아는 건 별로 없지만) 가족입니다        미리내 성지  playground
# 4        drama          (아는 건 별로 없지만) 가족입니다           초은당  playground
# ...        ...                          ...           ...         ...
# 15029    drama  You Raise Me Up (유 레이즈 미 업)   서울마리나 클럽&요트  playground
# 15030    drama  You Raise Me Up (유 레이즈 미 업)          한강대교  playground
# 15031    drama  You Raise Me Up (유 레이즈 미 업)      해밀톤 호텔별관        stay
# 15032    drama  You Raise Me Up (유 레이즈 미 업)        북촌로5가길  playground
# 15033    drama  You Raise Me Up (유 레이즈 미 업)           청계천  playground
#
#                               ADDR      LC_LA      LC_LO ADDR_area
# ...
