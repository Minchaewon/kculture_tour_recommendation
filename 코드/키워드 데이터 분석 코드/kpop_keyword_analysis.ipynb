# %% [markdown]
# ### <b>인도네시아(ID) Kpop 키워드 분석</b>
# * COLCT_DE : 수집일자(2017-01 ~ 2019-11)
# * COUNTRY_CD : 국가코드(ID)
# * CHNNEL_NM : 채널명
# * Community_Key_W : 커뮤니티 키워드
# * KWRD_FQ_CO : 키워드 빈도수
# * FILE_NM : 파일명
# * BASE_DE : 기준일자

# %%
import pandas as pd 
import numpy as np      

# csv 파일 열기
data_ID = pd.read_csv("D:\김가경\활동\OUTLIER\data\KEYWORD_KPOP_ID.csv", encoding='utf-8')
data_ID
# Out:
#       COLCT_DE COUNTRY_CD  CHNNEL_NM Community_KEY_W  KWRD_FQ_CO  FILE_NM  \
# 0      2017-01         id  community            kpop        85.0      NaN
# 1      2017-01         id  community         youtube        36.0      NaN
# 2      2017-01         id  community             bts        25.0      NaN
# 3      2017-01         id  community          cnblue        10.0      NaN
# 4      2017-01         id  community             exo         8.0      NaN
# ...        ...        ...        ...             ...         ...      ...
# 65529      NaN        NaN        NaN             NaN         NaN      NaN
# 65530      NaN        NaN        NaN             NaN         NaN      NaN
# 65531      NaN        NaN        NaN             NaN         NaN      NaN
# 65532      NaN        NaN        NaN             NaN         NaN      NaN
# 65533      NaN        NaN        NaN             NaN         NaN      NaN
#
#        BASE_DE
# 0          NaN
# 1          NaN
# 2          NaN
# ...

# %%
# nan 값 개수 확인 후 제거
nan_data = data_ID['COLCT_DE'].isna().sum()
print(nan_data)
df_ID = data_ID.dropna(subset = ['COLCT_DE'])
df_ID
# Out:
# 65280
#     COLCT_DE COUNTRY_CD  CHNNEL_NM Community_KEY_W  KWRD_FQ_CO  FILE_NM  \
# 0    2017-01         id  community            kpop        85.0      NaN
# 1    2017-01         id  community         youtube        36.0      NaN
# 2    2017-01         id  community             bts        25.0      NaN
# 3    2017-01         id  community          cnblue        10.0      NaN
# 4    2017-01         id  community             exo         8.0      NaN
# ..       ...        ...        ...             ...         ...      ...
# 249  2019-10         id  community            fans         2.0      NaN
# 250  2019-10         id  community           songs         2.0      NaN
# 251  2019-11         id  community            kpop        77.0      NaN
# 252  2019-11         id  community           idols         5.0      NaN
# 253  2019-11         id  community         jackson         5.0      NaN
#
#      BASE_DE
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ...

# %%
df_ID.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 254 entries, 0 to 253
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   COLCT_DE         254 non-null    object
#  1   COUNTRY_CD       254 non-null    object
#  2   CHNNEL_NM        254 non-null    object
#  3   Community_KEY_W  254 non-null    object
#  4   KWRD_FQ_CO       254 non-null    float64
#  5   FILE_NM          0 non-null      float64
#  6   BASE_DE          0 non-null      float64
# dtypes: float64(3), object(4)
# memory usage: 15.9+ KB

# %%
# Community_KEY_W 값 확인 : 52개
df_ID['Community_KEY_W'].unique()
# df['Community_KEY_W'].nunique()
# Out:
# array(['kpop', 'youtube', 'bts', 'cnblue', 'exo', 'amp', 'nct', 'seohyun',
#        'saya', 'suka', 'melon', 'allkpop', 'jyp', 'mnet', 'music',
#        'jackson', 'song', 'fanmeeting', 'btstwt', 'award', 'artist',
#        'seventeen', 'twice', 'dreamconcert', 'kchart', 'album', 'fancam',
#        'fandom', 'fans', 'mama', 'idol', 'songs', 'idols', 'jam', 'ikon',
#        'mbc', 'bangtan', 'comeback', 'mutuals', 'blackpink', 'bigbang',
#        'gangnam', 'baekhyun', 'rose', 'yugyeom', 'bambam', 'korea',
#        'billboard', 'fan', 'yeji', 'artists', 'jennie'], dtype=object)

# %%
# Community_KEY_W 값 별로 KWRD_FQ_CO 합계 구하기
merged_df_ID = df_ID.groupby('Community_KEY_W')['KWRD_FQ_CO'].sum().reset_index()
merged_df_ID = merged_df.sort_values(by='KWRD_FQ_CO', ascending=False)
merged_df_ID
# Out:
#    Community_KEY_W  KWRD_FQ_CO
# 33            kpop      3433.0
# 50         youtube      1291.0
# 12             bts       553.0
# 13          btstwt       236.0
# 3           artist       203.0
# 38           music       202.0
# 47            suka       172.0
# 42            saya       166.0
# 17             exo       164.0
# 4          artists       122.0
# 27         jackson        75.0
# 2              amp        66.0
# 24            idol        61.0
# 48           twice        52.0
# 22            fans        51.0
# 40             nct        45.0
# 1          allkpop        45.0
# 45            song        41.0
# 28             jam        24.0
# 11       blackpink        21.0
# 46           songs        18.0
# 19          fancam        17.0
# 34            mama        15.0
# 23         gangnam        15.0
# 18             fan        14.0
# 32           korea        14.0
# 39         mutuals        13.0
# 0            album        13.0
# 44       seventeen        12.0
# ...

# %%
# 빈도 수 기준으로 워드클라우드 생성
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wordcloud_data_ID = merged_df_ID.set_index('Community_KEY_W')['KWRD_FQ_CO']
wordcloud_ID = WordCloud(background_color='white').generate_from_frequencies(wordcloud_data_ID)

# 워드 클라우드 시각화
plt.imshow(wordcloud_ID, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ### <b>베트남(VN) Kpop 키워드 분석</b>
# * COLCT_DE : 수집일자(2017-01 ~ 2019-11)
# * COUNTRY_CD : 국가코드(ID)
# * CHNNEL_NM : 채널명
# * CMNTY_KWARD_NM : 커뮤니티 키워드
# * KWRD_FQ_CO : 키워드 빈도수
# * FILE_NM : 파일명
# * BASE_DE : 기준일자

# %%
# csv 파일 열기
data_VN = pd.read_csv("D:\김가경\활동\OUTLIER\data\KEYWORD_KPOP_VN.csv", encoding='utf-8')
data_VN
# Out:
#       COLCT_DE COUNTRY_CD  CHNNEL_NM CMNTY_KWRD_NM  KWRD_FQ_CO  FILE_NM  \
# 0      2017-01         vn  community          kpop        14.0      NaN
# 1      2017-01         vn  community       youtube         6.0      NaN
# 2      2017-01         vn  community           clc         4.0      NaN
# 3      2017-01         vn  community       seohyun         3.0      NaN
# 4      2017-02         vn  community          kpop         5.0      NaN
# ...        ...        ...        ...           ...         ...      ...
# 65529      NaN        NaN        NaN           NaN         NaN      NaN
# 65530      NaN        NaN        NaN           NaN         NaN      NaN
# 65531      NaN        NaN        NaN           NaN         NaN      NaN
# 65532      NaN        NaN        NaN           NaN         NaN      NaN
# 65533      NaN        NaN        NaN           NaN         NaN      NaN
#
#        BASE_DE
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...

# %%
# nan 값 개수 확인 후 제거
nan_data = data_VN['COLCT_DE'].isna().sum()
print(nan_data)
# Out:
# 65391

# %%
df_VN = data_VN.dropna(subset = ['COLCT_DE'])
df_VN
# Out:
#     COLCT_DE COUNTRY_CD  CHNNEL_NM CMNTY_KWRD_NM  KWRD_FQ_CO  FILE_NM  BASE_DE
# 0    2017-01         vn  community          kpop        14.0      NaN      NaN
# 1    2017-01         vn  community       youtube         6.0      NaN      NaN
# 2    2017-01         vn  community           clc         4.0      NaN      NaN
# 3    2017-01         vn  community       seohyun         3.0      NaN      NaN
# 4    2017-02         vn  community          kpop         5.0      NaN      NaN
# ..       ...        ...        ...           ...         ...      ...      ...
# 138  2019-10         vn  community          fans         1.0      NaN      NaN
# 139  2019-10         vn  community        itunes         1.0      NaN      NaN
# 140  2019-10         vn  community          jtbc         1.0      NaN      NaN
# 141  2019-11         vn  community          kpop        16.0      NaN      NaN
# 142  2019-11         vn  community        itunes         6.0      NaN      NaN
#
# [143 rows x 7 columns]

# %%
df_VN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 143 entries, 0 to 142
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   COLCT_DE       143 non-null    object
#  1   COUNTRY_CD     143 non-null    object
#  2   CHNNEL_NM      143 non-null    object
#  3   CMNTY_KWRD_NM  143 non-null    object
#  4   KWRD_FQ_CO     143 non-null    float64
#  5   FILE_NM        0 non-null      float64
#  6   BASE_DE        0 non-null      float64
# dtypes: float64(3), object(4)
# memory usage: 8.9+ KB

# %%
# Community_KEY_W 값 확인 : 47개
df_VN['CMNTY_KWRD_NM'].unique()
df_VN['CMNTY_KWRD_NM'].nunique()
# Out:
# 47

# %%
# Community_KEY_W 값 별로 KWRD_FQ_CO 합계 구하기
merged_df_VN = df_VN.groupby('CMNTY_KWRD_NM')['KWRD_FQ_CO'].sum().reset_index()
merged_df_VN = merged_df_VN.sort_values(by='KWRD_FQ_CO', ascending=False)
merged_df_VN.head(5)
# Out:
#    CMNTY_KWRD_NM  KWRD_FQ_CO
# 30          kpop       926.0
# 8            bts       297.0
# 46       youtube       232.0
# 38       scandal       190.0
# 10        btstwt       118.0

# %%
# 빈도 수 기준으로 워드클라우드 생성
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wordcloud_data_VN = merged_df_VN.set_index('CMNTY_KWRD_NM')['KWRD_FQ_CO']
wordcloud_VN = WordCloud(background_color='white').generate_from_frequencies(wordcloud_data_VN)

# 워드 클라우드 시각화
plt.imshow(wordcloud_VN, interpolation='bilinear')
plt.axis('off')
plt.show()
